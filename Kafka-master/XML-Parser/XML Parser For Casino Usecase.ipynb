# %%
pip install xmlschema
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 7, Finished, Available, Finished)
# Collecting xmlschema
#   Downloading xmlschema-3.4.2-py3-none-any.whl (417 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.8/417.8 kB 20.3 MB/s eta 0:00:00
# Collecting elementpath<5.0.0,>=4.4.0 (from xmlschema)
#   Downloading elementpath-4.5.0-py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.8/228.8 kB 91.8 MB/s eta 0:00:00
# Installing collected packages: elementpath, xmlschema
# Successfully installed elementpath-4.5.0 xmlschema-3.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DecimalType
import xmlschema

spark = SparkSession.builder \
    .appName("Lakehouse XML XSD") \
    .config("spark.jars.packages", "com.databricks:spark-xml_2.12:0.12.0") \
    .getOrCreate()

# Step 1: Parse the XSD file to define the table structure
xsd_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/casino_data_schema.xsd"  # Adjust to your XSD file path
xml_path = "/lakehouse/default/Files/casino_data.xml"  # Adjust to your XML file path

# Load the XSD schema
xsd_schema = xmlschema.XMLSchema(xsd_path)

# Function to map XSD types to PySpark types
def get_spark_type(xsd_type):
    if xsd_type == "string":
        return StringType()
    elif xsd_type == "int":
        return IntegerType()
    elif xsd_type == "decimal":
        return DecimalType(10, 2)  # You can adjust precision and scale
    # Add more mappings as needed
    return StringType()  # Default fallback

# Extract schema details from XSD
fields = []
for element in xsd_schema.elements.values():
    field_name = element.name
    data_type = element.type.local_name
    fields.append(StructField(field_name, get_spark_type(data_type), True))

# Create the DataFrame schema
schema = StructType(fields)

# Step 2: Read XML data using the generated schema
df = spark.read \
    .format("xml") \
    .schema(schema) \
    .load(xml_path)

# Step 3: Show the DataFrame
df.show()
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 15, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# Cell In[37], line 15
#      12 xml_path = "/lakehouse/default/Files/casino_data.xml"  # Adjust to your XML file path
#      14 # Load the XSD schema
# ---> 15 xsd_schema = xmlschema.XMLSchema(xsd_path)
#      17 # Function to map XSD types to PySpark types
#      18 def get_spark_type(xsd_type):
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/xmlschema/validators/schemas.py:349, in XMLSchemaBase.__init__(self, source, namespace, validation, global_maps, converter, locations, base_url, allow, defuse, timeout, uri_mapper, build, use_meta, use_fallback, use_xpath3, loglevel)
#     347     self.source = source
#     348 else:
# --> 349     self.source = XMLResource(
#     350         source, base_url, allow, defuse, timeout, uri_mapper=uri_mapper
#     351     )
#     353 logger.debug("Read schema from %r", self.source.url or self.source.source)
#     355 self.imports = {}
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/xmlschema/resources.py:258, in XMLResource.__init__(self, source, base_url, allow, defuse, timeout, lazy, thin_lazy, uri_mapper)
#     255     raise XMLSchemaTypeError(msg % type(uri_mapper))
#     256 self._uri_mapper = uri_mapper
# --> 258 self.parse(source, lazy)
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/xmlschema/resources.py:613, in XMLResource.parse(self, source, lazy)
#     609 if is_url(source):
#     610     # source is a string containing a URL or a file path
#     611     url = self._get_parsed_url(source.strip())
# --> 613     with urlopen(url, timeout=self._timeout) as resource:
#     614         self._parse_resource(resource, url, lazy)
#     616     self._text = None
#
# File ~/cluster-env/trident_env/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/cluster-env/trident_env/lib/python3.10/urllib/request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File ~/cluster-env/trident_env/lib/python3.10/urllib/request.py:541, in OpenerDirector._open(self, req, data)
#     538 if result:
#     539     return result
# --> 541 return self._call_chain(self.handle_open, 'unknown',
#     542                         'unknown_open', req)
#
# File ~/cluster-env/trident_env/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File ~/cluster-env/trident_env/lib/python3.10/urllib/request.py:1419, in UnknownHandler.unknown_open(self, req)
#    1417 def unknown_open(self, req):
#    1418     type = req.type
# -> 1419     raise URLError('unknown url type: %s' % type)
#
# URLError: <urlopen error unknown url type: abfss>

# %%
from pyspark.sql import SparkSession
import xmlschema
import os
import xml.etree.ElementTree as ET
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DecimalType, TimestampType

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Lakehouse XML XSD Reader") \
    .getOrCreate()

# Set your ABFS path
abfs_xsd_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/casino_data_schema.xsd"  # Update with your actual path

# Step 1: Read the XSD file into memory
xsd_df = spark.read.text(abfs_xsd_path)

# Write the XSD content to a local temporary file
local_xsd_path = "/tmp/casino_data_schema.xsd"  # Temporary local path
xsd_content = "\n".join(row.value for row in xsd_df.collect())

# Save to local path
with open(local_xsd_path, "w") as f:
    f.write(xsd_content)

# Step 2: Load the XSD schema using xmlschema
xsd_schema = xmlschema.XMLSchema(local_xsd_path)

# Function to parse XSD and create a schema
def parse_xsd(xsd_file):
    tree = ET.parse(xsd_file)
    root = tree.getroot()
    schema = {}
    
    # Iterate through elements in XSD
    for complex_type in root.findall('.//xs:complexType', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
        type_name = complex_type.get('name')
        fields = []
        
        for sequence in complex_type.findall('.//xs:sequence', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
            for element in sequence.findall('xs:element', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
                field_name = element.get('name')
                field_type = element.get('type')
                # Map XSD types to Spark types
                spark_type = None
                if field_type == 'xs:string':
                    spark_type = StringType()
                elif field_type == 'xs:int':
                    spark_type = IntegerType()
                elif field_type == 'xs:decimal':
                    spark_type = DecimalType()
                elif field_type == 'xs:dateTime':
                    spark_type = TimestampType()
                
                if spark_type is not None:
                    fields.append(StructField(field_name, spark_type, True))
        
        schema[type_name] = StructType(fields)
    
    return schema

# Extract row tags
def extract_row_tags(xsd_path):
    # Parse the XSD file
    schema_tree = ET.parse(xsd_path)
    root = schema_tree.getroot()

    # Find all complex types with sequence elements
    row_tags = []
    for complex_type in root.findall('.//xs:complexType', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
        for sequence in complex_type.findall('./xs:sequence', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
            for element in sequence.findall('xs:element', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
                row_tags.append(element.attrib['name'])

    return row_tags

row_tags = extract_row_tags(local_xsd_path)

# Load the XML data
xml_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/casino_data.xml"  # Adjust to your XML file path

# Read XML data for each row tag dynamically
schema = parse_xsd(local_xsd_path)

# Dictionary to store DataFrames for each row tag
dataframes = {}

for tag in row_tags:
    # Read the XML file for the current row tag
    df = spark.read \
        .format("xml") \
        .option("rowTag", tag) \
        .load(xml_path)

    # Dynamically select columns based on parsed schema
    if tag in schema:
        df = df.select(*[f"{tag}.{field.name}" for field in schema[tag].fields])
    
    # Store the DataFrame in the dictionary
    dataframes[tag] = df
    
    # Create a temporary table/view for SQL queries
    df.createOrReplaceTempView(tag)
    
    print(f"Data for {tag}:")
    #df.show(truncate=False)

print('new line')
print(dataframes)
#for table_name, df in dataframes.items():
 #   if df is not None and not df.isEmpty():  # Check if the DataFrame is not empty
        # Write the DataFrame to the Lakehouse as a Parquet file
 #       df.write.mode("overwrite").format("delta").saveAsTable(table_name)
 #   else:
 #       print(f"DataFrame for {table_name} is empty or None, skipping...")
# Clean up the local XSD file if needed
os.remove(local_xsd_path)
for tag in row_tags:
    print(f"Processing table for {tag}:")

    # Dynamically construct table name
    table_name = f"{tag}_table"  # Example: for tag 'user', table_name becomes 'user_table'
    
    # Query the temporary view created for the tag
    temp_df = spark.sql(f"SELECT * FROM {tag}")

    # Check if the DataFrame is not empty
    if temp_df is not None and not temp_df.isEmpty():
        # Write the DataFrame to the Lakehouse in Delta format
        temp_df.write.mode("overwrite").format("delta").option("overwriteSchema", "true").saveAsTable(table_name)

        # Display the content of the saved table (optional)
        print(f"Table {table_name} data:")
        spark.sql(f"SELECT * FROM {table_name}").show(truncate=False)
    else:
        print(f"DataFrame for {table_name} is empty or None, skipping...")
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 46, Finished, Available, Finished)
# Data for users:
# Data for games:
# Data for transactions:
# Data for user:
# Data for user_id:
# Data for username:
# Data for email:
# Data for password_hash:
# Data for balance:
# Data for registration_date:
# Data for status:
# Data for game:
# Data for game_id:
# Data for name:
# Data for type:
# Data for min_bet:
# Data for max_bet:
# Data for provider:
# Data for transaction:
# Data for transaction_id:
# Data for user_id:
# Data for amount:
# Data for transaction_type:
# Data for transaction_date:
# Data for game_id:
# Data for status:
# new line
# {'users': DataFrame[user: array<struct<balance:double,email:string,password_hash:string,registration_date:timestamp,status:string,user_id:bigint,username:string>>], 'games': DataFrame[game: array<struct<game_id:bigint,max_bet:double,min_bet:double,name:string,provider:string,type:string>>], 'transactions': DataFrame[transaction: array<struct<amount:double,game_id:bigint,status:string,transaction_date:timestamp,transaction_id:bigint,transaction_type:string,user_id:bigint>>], 'user': DataFrame[balance: double, email: string, password_hash: string, registration_date: timestamp, status: string, user_id: bigint, username: string], 'user_id': DataFrame[], 'username': DataFrame[], 'email': DataFrame[], 'password_hash': DataFrame[], 'balance': DataFrame[], 'registration_date': DataFrame[], 'status': DataFrame[], 'game': DataFrame[game_id: bigint, max_bet: double, min_bet: double, name: string, provider: string, type: string], 'game_id': DataFrame[], 'name': DataFrame[], 'type': DataFrame[], 'min_bet': DataFrame[], 'max_bet': DataFrame[], 'provider': DataFrame[], 'transaction': DataFrame[amount: double, game_id: bigint, status: string, transaction_date: timestamp, transaction_id: bigint, transaction_type: string, user_id: bigint], 'transaction_id': DataFrame[], 'amount': DataFrame[], 'transaction_type': DataFrame[], 'transaction_date': DataFrame[]}
# Processing table for users:
# Table users_table data:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user                                                                                                                                                                            |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{250.75, john.doe@example.com, abc123xyz, 2022-01-15 10:30:00, active, 1, john_doe}, {800.0, jane.smith@example.com, xyz456abc, 2021-05-22 14:45:00, suspended, 2, jane_smith}]|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Processing table for games:
# Table games_table data:
# +---------------------------------------------------------------------------------------------------------+
# |game                                                                                                     |
# +---------------------------------------------------------------------------------------------------------+
# |[{1, 100.0, 1.0, Lucky Slots, SpinTech, slot}, {2, 500.0, 5.0, Blackjack Royale, CardMasters, blackjack}]|
# +---------------------------------------------------------------------------------------------------------+
#
# Processing table for transactions:
# Table transactions_table data:
# +----------------------------------------------------------------------------------------------------------------------+
# |transaction                                                                                                           |
# +----------------------------------------------------------------------------------------------------------------------+
# |[{500.0, 1, completed, 2023-09-01 10:15:00, 1, deposit, 1}, {50.0, 2, pending, 2023-09-02 11:00:00, 2, withdrawal, 2}]|
# +----------------------------------------------------------------------------------------------------------------------+
#
# Processing table for user:
# Table user_table data:
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
# |balance|email                 |password_hash|registration_date  |status   |user_id|username  |
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
# |250.75 |john.doe@example.com  |abc123xyz    |2022-01-15 10:30:00|active   |1      |john_doe  |
# |800.0  |jane.smith@example.com|xyz456abc    |2021-05-22 14:45:00|suspended|2      |jane_smith|
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
#
# Processing table for user_id:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[130], line 130
#     127 # Check if the DataFrame is not empty
#     128 if temp_df is not None and not temp_df.isEmpty():
#     129     # Write the DataFrame to the Lakehouse in Delta format
# --> 130     temp_df.write.mode("overwrite").format("delta").option("overwriteSchema", "true").saveAsTable(table_name)
#     132     # Display the content of the saved table (optional)
#     133     print(f"Table {table_name} data:")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:1521, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#    1519 if format is not None:
#    1520     self.format(format)
# -> 1521 self._jwrite.saveAsTable(name)
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: Data used in creating the Delta table doesn't have any columns.

# %%
from pyspark.sql import SparkSession
import xmlschema
import os
import xml.etree.ElementTree as ET
from pyspark.sql.functions import explode
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DecimalType, TimestampType

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Lakehouse XML XSD Reader") \
    .getOrCreate()

# Set your ABFS path
abfs_xsd_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/casino_data_schema.xsd"  # Update with your actual path

# Step 1: Read the XSD file into memory
xsd_df = spark.read.text(abfs_xsd_path)

# Write the XSD content to a local temporary file
local_xsd_path = "/tmp/casino_data_schema.xsd"  # Temporary local path
xsd_content = "\n".join(row.value for row in xsd_df.collect())

# Save to local path
with open(local_xsd_path, "w") as f:
    f.write(xsd_content)

# Step 2: Load the XSD schema using xmlschema
xsd_schema = xmlschema.XMLSchema(local_xsd_path)

# Function to parse XSD and create a schema
def parse_xsd(xsd_file):
    tree = ET.parse(xsd_file)
    root = tree.getroot()
    schema = {}
    
    # Iterate through elements in XSD
    for complex_type in root.findall('.//xs:complexType', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
        type_name = complex_type.get('name')
        fields = []
        
        for sequence in complex_type.findall('.//xs:sequence', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
            for element in sequence.findall('xs:element', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
                field_name = element.get('name')
                field_type = element.get('type')
                # Map XSD types to Spark types
                spark_type = None
                if field_type == 'xs:string':
                    spark_type = StringType()
                elif field_type == 'xs:int':
                    spark_type = IntegerType()
                elif field_type == 'xs:decimal':
                    spark_type = DecimalType()
                elif field_type == 'xs:dateTime':
                    spark_type = TimestampType()
                
                if spark_type is not None:
                    fields.append(StructField(field_name, spark_type, True))
        
        schema[type_name] = StructType(fields)
    
    return schema

# Extract row tags (the high-level elements like users, games, transactions)
def extract_row_tags(xsd_path):
    # Parse the XSD file
    schema_tree = ET.parse(xsd_path)
    root = schema_tree.getroot()

    # Find all the top-level row tags
    row_tags = []
    for element in root.findall('.//xs:element', namespaces={'xs': 'http://www.w3.org/2001/XMLSchema'}):
        row_tags.append(element.attrib['name'])
    
    return row_tags

row_tags = extract_row_tags(local_xsd_path)

# Load the XML data
xml_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/casino_data.xml"  # Adjust to your XML file path

# Read the XML data at the top level (casino)
df = spark.read \
    .format("xml") \
    .option("rowTag", "casino") \
    .load(xml_path)

# Now, parse the XSD schema for field structures
schema = parse_xsd(local_xsd_path)

# Dictionary to store DataFrames for each high-level tag (users, games, transactions)
dataframes = {}

# Process each row tag (e.g., users, games, transactions)
for tag in row_tags:
    # Extract the respective DataFrame
    if tag == "users":
        users_df = df.select(explode("users.user").alias("user")).select("user.*")
        dataframes["users"] = users_df
    elif tag == "games":
        games_df = df.select(explode("games.game").alias("game")).select("game.*")
        dataframes["games"] = games_df
    elif tag == "transactions":
        transactions_df = df.select(explode("transactions.transaction").alias("transaction")).select("transaction.*")
        dataframes["transactions"] = transactions_df

# Display the DataFrames
for tag, df in dataframes.items():
    print(f"Data for {tag}:")
    df.show(truncate=False)

# Write each DataFrame to the Lakehouse as a Delta table
for tag, df in dataframes.items():
    table_name = f"{tag}_table"  # e.g., users_table, games_table, etc.
    

# Clean up the local XSD file if needed
os.remove(local_xsd_path)
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 58, Finished, Available, Finished)
# Data for users:
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
# |balance|email                 |password_hash|registration_date  |status   |user_id|username  |
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
# |250.75 |john.doe@example.com  |abc123xyz    |2022-01-15 10:30:00|active   |1      |john_doe  |
# |800.0  |jane.smith@example.com|xyz456abc    |2021-05-22 14:45:00|suspended|2      |jane_smith|
# +-------+----------------------+-------------+-------------------+---------+-------+----------+
#
# Data for games:
# +-------+-------+-------+----------------+-----------+---------+
# |game_id|max_bet|min_bet|name            |provider   |type     |
# +-------+-------+-------+----------------+-----------+---------+
# |1      |100.0  |1.0    |Lucky Slots     |SpinTech   |slot     |
# |2      |500.0  |5.0    |Blackjack Royale|CardMasters|blackjack|
# +-------+-------+-------+----------------+-----------+---------+
#
# Data for transactions:
# +------+-------+---------+-------------------+--------------+----------------+-------+
# |amount|game_id|status   |transaction_date   |transaction_id|transaction_type|user_id|
# +------+-------+---------+-------------------+--------------+----------------+-------+
# |500.0 |1      |completed|2023-09-01 10:15:00|1             |deposit         |1      |
# |50.0  |2      |pending  |2023-09-02 11:00:00|2             |withdrawal      |2      |
# +------+-------+---------+-------------------+--------------+----------------+-------+

# %%
# %%sql
# select * from user_id;
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 53, Finished, Available, Finished)
# <Spark SQL result set with 4 rows and 0 fields>

# %%
import os

# File paths to check
xsd_path = "./builtin/casino_data_schema.xsd"
xml_path = "./builtin/Customer.csv"

# Check if files exist
if os.path.exists(xsd_path):
    print(f"XSD file {xsd_path} exists.")
else:
    print(f"XSD file {xsd_path} does not exist.")

if os.path.exists(xml_path):
    print(f"XML file {xml_path} exists.")
else:
    print(f"XML file {xml_path} does not exist.")
# Out:
# StatementMeta(, 75ddc290-a293-4c13-874c-badee122e0e8, 25, Finished, Available, Finished)
# XSD file ./builtin/casino_data_schema.xsd exists.
# XML file ./builtin/Customer.csv exists.

# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Lakehouse CSV Reader") \
    .getOrCreate()

# Ensure this path is correct and accessible
csv_path = "abfss://ed9bea8b-5f1a-4dbe-a49e-4cc0009f02db@onelake.dfs.fabric.microsoft.com/772c1423-20a6-4e59-84ee-d82652f1f1e8/Files/Customer.csv"  # Use a descriptive variable name for clarity

# Try loading the CSV file
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(csv_path)

# Show the DataFrame
df.show()
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 9, Finished, Available, Finished)
# +-----------+------------------+----------------+------------+------------+--------------------+--------------+-------------+--------------------+-----------+-------------+-------------------+-------------------+-------------------+
# |Customer_ID|              Name|        Password| Cell_Number|Phone_Number|               Email|         State|         City|             Address|Postal Code|Date of Birth|         CreditCard|   Registrationdate|Last logged in time|
# +-----------+------------------+----------------+------------+------------+--------------------+--------------+-------------+--------------------+-----------+-------------+-------------------+-------------------+-------------------+
# |          1|     Ingaberg Spir|yH6/7119!NfyiK}k|520 323 5886|404 567 0963|   ispir0@zimbio.com|       Arizona|       Tucson| 7836 Brown Junction|      85737|    9/30/1994|   3553975076398062|2013-09-02 07:12:04|2018-01-21 01:34:22|
# |          2|      Morna Jewers|   gB1/PJw`ZhY\v|508 654 2980|202 529 6253|mjewers1@tripadvi...| Massachusetts|       Newton|    45 Kenwood Place|      02162|   11/27/1976|   5554229352430379|2017-11-13 14:09:57|2017-05-21 04:20:34|
# |          3|    Melisenda Gerg|      jZ2$,tvNsd|234 583 8476|305 605 5358|     mgerg2@about.me|          Ohio|       Canton|02 Clyde Gallaghe...|      44760|     1/2/1971|   3571945861772357|2017-09-04 17:27:41|2017-07-31 13:01:26|
# |          4|    Lindy Pettican|    lL5`DwnBSai1|912 872 9727|757 303 0596|lpettican3@behanc...|       Georgia|     Savannah|  6575 Carioca Place|      31410|    6/17/1948|   3571909597542435|2010-11-18 09:44:06|2017-12-04 02:10:25|
# |          5|        Ray Gartan|     qR4).RVqV5%|310 514 2870|940 511 7361|rgartan4@google.c...|    California|San Francisco|        4 Nobel Park|      94105|    1/28/1983|   5602254750389540|2013-08-12 08:53:01|2017-02-10 07:40:27|
# |          6|    Farlie Thursby| tP8}dI46BWxh1yS|314 928 3760|937 266 5790|   fthursby5@mapy.cz|      Missouri|  Saint Louis|10730 Crest Line ...|      63196|    8/17/1946| 630485422541837146|2016-11-23 01:20:48|2017-12-30 06:52:18|
# |          7| Trumaine Lonsdale|    eJ2&09>#Sn\N|504 146 2495|619 739 9937|tlonsdale6@yahoo....|     Louisiana|  New Orleans|      5 Kenwood Pass|      70154|    6/15/1999|   3581376312262020|2014-08-31 12:18:09|2017-11-13 19:36:51|
# |          8|Aguistin Gronaller|     rZ8'wazAylr|716 402 8915|415 693 2231|agronaller7@abc.n...|      New York|      Buffalo|37810 Glendale St...|      14220|    2/22/1981|   3536590595974830|2011-11-12 03:48:25|2017-03-08 16:08:58|
# |          9|   Carlo Benettolo|     cH5=|b%PGqe|208 920 8845|203 504 1137|cbenettolo8@alter...|         Idaho|        Boise|    7505 Derek Trail|      83732|   12/15/1938|   3542067147511479|2012-02-11 20:03:54|2018-01-28 13:27:48|
# |         10|   Ailbert Spurdle|      cT5+|YcC>O|713 116 1377|502 703 4866|   aspurdle9@cdc.gov|         Texas|      Houston|     83 Corben Trail|      77065|     8/9/1991|   3566581405843904|2011-11-24 17:54:16|2017-05-26 16:56:57|
# |         11|     Marijn Gibben| uX1_nuh$<7?#c6J|713 479 4610|915 853 5731|   mgibbena@fema.gov|         Texas|      Houston|  827 Goodland Point|      77271|   11/14/1991|   3549405215319263|2013-01-14 18:53:56|2017-08-15 07:52:44|
# |         12|     Saxon MacKall|    "gI7""x=_*B"|319 683 7290|215 694 7619| smackallb@patch.com|          Iowa|     Waterloo|549 Killdeer Terrace|      50706|     6/3/1970|   6387479590678526|2017-04-15 20:09:02|2017-06-09 19:22:05|
# |         13|    Kevon Southorn|   hD2/Z/YSs/..q|915 997 5717|415 946 1628|ksouthornc@thetim...|         Texas|      El Paso|  8 Saint Paul Alley|      79905|     8/7/1998|     30040084049428|2015-03-10 10:20:15|2017-06-04 03:20:44|
# |         14|  Brannon Poytress|   mZ8+Vq91?OE+P|813 615 8699|216 739 0892|bpoytressd@amazon...|       Florida|  Zephyrhills| 4434 Pearson Center|      33543|    10/4/1978|0604888130193420784|2011-04-24 22:28:22|2017-06-08 09:16:02|
# |         15|      Sofia Crumly|        oK8#6,&u|419 339 0513|336 159 8844|scrumlye@goodread...|          Ohio|       Toledo|     7 Caliangt Pass|      43656|   11/17/1990|   5038013554637726|2017-04-18 11:58:39|2017-08-29 16:08:25|
# |         16|        Boyce Pray|        zR4#VTY@|714 656 2013|701 749 5682|     bprayf@cnbc.com|    California| Garden Grove|     62 Graedel Pass|      92844|     4/4/1941|   3582777390448564|2012-09-28 01:18:12|2017-07-10 14:57:42|
# |         17|       Zenia Mairs| uM9<7\=u(Ltk?De|325 829 6629|360 446 2258| zmairsg@comsenz.com|         Texas|      Abilene| 4613 Service Circle|      79699|   12/15/1951|   6383051593175265|2014-11-23 22:31:21|2017-08-27 08:06:48|
# |         18| Daisey Qualtrough| yT6#}l&BJ5*/F(@|304 396 1660|610 219 6795|dqualtroughh@xinh...| West Virginia|   Huntington|  9021 Mayfield Road|      25770|    3/18/1980|   3563369626893459|2015-06-13 14:32:53|2017-09-09 13:45:17|
# |         19|     Adeline Gater|zG3!t5l}Q).zs!0P|309 141 3195|209 479 3484|  agateri@seesaa.net|      Illinois|       Peoria|5 Prairie Rose Ci...|      61605|     2/8/1958|   3559756404253557|2015-05-12 00:36:28|2017-08-29 06:10:10|
# |         20|    Ettore Tatford|  zW5!p$qivhzjIO|803 821 9673|617 601 9853|etatfordj@mayocli...|South Carolina|     Columbia|   7 Sunnyside Court|      29220|     7/8/1931|     30396215370368|2015-12-10 00:41:54|2017-07-21 17:09:49|
# +-----------+------------------+----------------+------------+------------+--------------------+--------------+-------------+--------------------+-----------+-------------+-------------------+-------------------+-------------------+
# only showing top 20 rows

# %%
# Import necessary modules
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, TimestampType
from pyspark.sql.functions import from_json, col, count
from pyspark.sql import functions as F

# Initialize Spark Session
spark = SparkSession.builder \
    .appName("Kafka Integration") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0") \
    .getOrCreate()

# Kafka configuration
kafka_bootstrap_servers = "158.220.124.0:9094"  # Replace with your Kafka broker address

# Define the schema for customer data
customer_schema = StructType() \
    .add("customer_id", IntegerType()) \
    .add("first_name", StringType()) \
    .add("last_name", StringType()) \
    .add("email", StringType()) \
    .add("phone_number", StringType()) \
    .add("passport_number", StringType()) \
    .add("nationality", StringType())

pnr_schema = StructType([
    StructField("pnr_id", StringType(), True),
    StructField("customer_id", IntegerType(), True),
    StructField("flight_number", StringType(), True),
    StructField("departure_airport", StringType(), True),
    StructField("arrival_airport", StringType(), True),
    StructField("departure_date", TimestampType(), True),
    StructField("arrival_date", TimestampType(), True),
    StructField("ticket_price", FloatType(), True),
    StructField("seat_number", StringType(), True),
    StructField("booking_status", StringType(), True),
    StructField("payment_method", StringType(), True),
    StructField("passport_number", StringType(), True)
])

# Read from Kafka
cus_df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", kafka_bootstrap_servers) \
    .option("subscribe", "customers_data") \
    .option("startingOffsets", "latest") \
    .option("failOnDataLoss", "false") \
    .load() \
    .selectExpr('CAST(value AS STRING)') \
    .select(from_json(col('value'), customer_schema).alias('data')).select('data.*')

pnr_df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", kafka_bootstrap_servers) \
    .option("subscribe", "pnr_data") \
    .option("startingOffsets", "latest") \
    .option("failOnDataLoss", "false") \
    .load() \
    .selectExpr('CAST(value AS STRING)') \
    .select(from_json(col('value'), pnr_schema).alias('data')).select('data.*')

# Add a timestamp column to each DataFrame
cus_df_with_timestamp = cus_df.withColumn("timestamp", F.current_timestamp())
pnr_df_with_timestamp = pnr_df.withColumn("timestamp", F.current_timestamp())

# Apply watermark on the DataFrames
cus_df_with_watermark = cus_df_with_timestamp.withWatermark("timestamp", "10 minutes")
pnr_df_with_watermark = pnr_df_with_timestamp.withWatermark("timestamp", "10 minutes")

# Write to Delta tables

# Write to Delta tables using saveAsTable

test_query = df.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", "Files/RealTime/test_checkpoint") \
    .start("test_bronze_table")  # New table name for testing

query2 = pnr_df.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", "Files/RealTime/pnr_checkpoint") \
    .start("bronze_pnr_table2")  # Use start with table name

# Start the query
test_query.awaitTermination()
# Out:
# StatementMeta(, 75ddc290-a293-4c13-874c-badee122e0e8, 35, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[97], line 76
#      70 pnr_df_with_watermark = pnr_df_with_timestamp.withWatermark("timestamp", "10 minutes")
#      72 # Write to Delta tables
#      73
#      74 # Write to Delta tables using saveAsTable
# ---> 76 test_query = df.writeStream \
#      77     .format("delta") \
#      78     .outputMode("append") \
#      79     .option("checkpointLocation", "Files/RealTime/test_checkpoint") \
#      80     .start("test_bronze_table")  # New table name for testing
#      82 query2 = pnr_df.writeStream \
#      83     .format("delta") \
#      84     .outputMode("append") \
#      85     .option("checkpointLocation", "Files/RealTime/pnr_checkpoint") \
#      86     .start("bronze_pnr_table2")  # Use start with table name
#      88 # Start the query
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:543, in DataFrame.writeStream(self)
#     512 @property
#     513 def writeStream(self) -> DataStreamWriter:
#     514     """
#     515     Interface for saving the content of the streaming :class:`DataFrame` out into external
#     516     storage.
#    (...)
#     541     ...     query.stop()
#     542     """
# --> 543     return DataStreamWriter(self)
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/streaming/readwriter.py:739, in DataStreamWriter.__init__(self, df)
#     737 self._df = df
#     738 self._spark = df.sparkSession
# --> 739 self._jwrite = df._jdf.writeStream()
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: [WRITE_STREAM_NOT_ALLOWED] `writeStream` can be called only on streaming Dataset/DataFrame.

# %%
#!/usr/bin/env python
# coding: utf-8

# ## FabricNotebook-To-ConnectKafka-Cluster
# 
# New notebook

# In[1]:


# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Kafka Integration") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0") \
    .getOrCreate()


# In[2]:


# Kafka configuration
kafka_bootstrap_servers = "158.220.124.0:9094"  # Replace with your Kafka broker address
kafka_topic = "customers_data"                     # Replace with your Kafka topic  test_topic

# Read from Kafka
df = spark \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", kafka_bootstrap_servers) \
  .option("subscribe", kafka_topic) \
  .option("startingOffsets", "latest") \
  .option("failOnDataLoss", "false")\
  .load()

# Convert Kafka message key and value from binary to string
kafka_df = df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Define a function to print each consumed message
def process_batch(df, batch_id):
    # Print the batch id and each row
    print(f"Processing batch {batch_id}:")
    for row in df.collect():
        print(f"Key: {row['key']}, Value: {row['value']}")

# Output each message and write to console
query = kafka_df.writeStream \
    .outputMode("append") \
    .format("console") \
    .foreachBatch(process_batch) \
    .option("checkpointLocation", "Files/RealTime/checkpoint") \
    .start()

query.awaitTermination()
# Out:
# StatementMeta(, 75ddc290-a293-4c13-874c-badee122e0e8, 38, Finished, Cancelled, Cancelled)
# Processing batch 1:
# Key: None, Value: {"customer_id": 1, "first_name": "Mark", "last_name": "Moreno", "email": "jasminesingh@example.net", "phone_number": "511.590.9332x024", "passport_number": "I04360617", "nationality": "Greenland"}
# Key: None, Value: {"customer_id": 2, "first_name": "Rachel", "last_name": "Herrera", "email": "matthewsjoshua@example.org", "phone_number": "+1-541-511-3413", "passport_number": "B88331200", "nationality": "Kuwait"}
# Key: None, Value: {"customer_id": 3, "first_name": "Abigail", "last_name": "Mcbride", "email": "mark67@example.org", "phone_number": "272-943-6872x110", "passport_number": "945878024", "nationality": "Afghanistan"}
# Key: None, Value: {"customer_id": 4, "first_name": "Katie", "last_name": "Wise", "email": "petersonrichard@example.net", "phone_number": "595.968.2058x811", "passport_number": "P79287707", "nationality": "Algeria"}
# Key: None, Value: {"customer_id": 5, "first_name": "Melissa", "last_name": "Nelson", "email": "josephhill@example.com", "phone_number": "(303)505-8016x395", "passport_number": "E70424544", "nationality": "Northern Mariana Islands"}
# Key: None, Value: {"customer_id": 6, "first_name": "Alice", "last_name": "Rowland", "email": "melissa30@example.org", "phone_number": "(463)952-3498x89828", "passport_number": "211853712", "nationality": "Argentina"}
# Key: None, Value: {"customer_id": 7, "first_name": "Christina", "last_name": "Ruiz", "email": "paulayang@example.net", "phone_number": "2688188152", "passport_number": "C26885625", "nationality": "Myanmar"}
# Key: None, Value: {"customer_id": 8, "first_name": "Julia", "last_name": "Bullock", "email": "sgonzalez@example.org", "phone_number": "+1-494-599-4829x04789", "passport_number": "893920816", "nationality": "Malta"}
# Key: None, Value: {"customer_id": 9, "first_name": "Darryl", "last_name": "Foster", "email": "paulawilliams@example.net", "phone_number": "(956)643-0806x2222", "passport_number": "876802832", "nationality": "Lao People's Democratic Republic"}
# Key: None, Value: {"customer_id": 10, "first_name": "David", "last_name": "Anderson", "email": "richardjohnson@example.com", "phone_number": "(329)632-8977x8642", "passport_number": "W55239697", "nationality": "Malawi"}
# Key: None, Value: {"customer_id": 11, "first_name": "Thomas", "last_name": "Rubio", "email": "jeffrey78@example.net", "phone_number": "+1-747-438-0895x28924", "passport_number": "651262523", "nationality": "Mozambique"}
# Key: None, Value: {"customer_id": 12, "first_name": "Hannah", "last_name": "Frey", "email": "moranpatricia@example.com", "phone_number": "528-715-9631", "passport_number": "817065781", "nationality": "Georgia"}
# Key: None, Value: {"customer_id": 13, "first_name": "Ashley", "last_name": "Sanders", "email": "patricia51@example.org", "phone_number": "(285)770-2702x55661", "passport_number": "364424759", "nationality": "French Southern Territories"}
# Key: None, Value: {"customer_id": 14, "first_name": "Deborah", "last_name": "Mathews", "email": "phampton@example.net", "phone_number": "648-672-5922x420", "passport_number": "871558100", "nationality": "Tuvalu"}
# Key: None, Value: {"customer_id": 15, "first_name": "Brianna", "last_name": "Lucas", "email": "andrewsrachel@example.com", "phone_number": "5419670550", "passport_number": "733631019", "nationality": "Guinea-Bissau"}
# Key: None, Value: {"customer_id": 16, "first_name": "Jennifer", "last_name": "Bautista", "email": "mcraig@example.org", "phone_number": "(801)877-4184x343", "passport_number": "932324933", "nationality": "Serbia"}
# Key: None, Value: {"customer_id": 17, "first_name": "Jason", "last_name": "Brown", "email": "bmills@example.com", "phone_number": "(223)374-7387", "passport_number": "489735831", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 18, "first_name": "Christopher", "last_name": "Dean", "email": "wendy89@example.org", "phone_number": "+1-386-939-5641x503", "passport_number": "654446457", "nationality": "Timor-Leste"}
# Key: None, Value: {"customer_id": 19, "first_name": "Christine", "last_name": "Rodriguez", "email": "csimpson@example.org", "phone_number": "(462)934-7249x754", "passport_number": "N87436660", "nationality": "Ethiopia"}
# Key: None, Value: {"customer_id": 20, "first_name": "Larry", "last_name": "Lambert", "email": "kara14@example.net", "phone_number": "(483)542-1117x27215", "passport_number": "Q62823255", "nationality": "New Caledonia"}
# Key: None, Value: {"customer_id": 21, "first_name": "Christopher", "last_name": "Green", "email": "smithashley@example.org", "phone_number": "675-741-5519", "passport_number": "411744863", "nationality": "Angola"}
# Key: None, Value: {"customer_id": 22, "first_name": "John", "last_name": "Phillips", "email": "pgriffin@example.com", "phone_number": "001-448-654-2404", "passport_number": "877584346", "nationality": "Tonga"}
# Key: None, Value: {"customer_id": 23, "first_name": "Zachary", "last_name": "Maxwell", "email": "ejackson@example.com", "phone_number": "(602)806-3441x1190", "passport_number": "440906172", "nationality": "United Kingdom"}
# Key: None, Value: {"customer_id": 24, "first_name": "Marilyn", "last_name": "Mckay", "email": "ramirezjackie@example.com", "phone_number": "(636)849-2847x86677", "passport_number": "J57078012", "nationality": "Benin"}
# Key: None, Value: {"customer_id": 25, "first_name": "Luke", "last_name": "Giles", "email": "jacobhorton@example.com", "phone_number": "(321)891-7146x108", "passport_number": "X78226789", "nationality": "Samoa"}
# Key: None, Value: {"customer_id": 26, "first_name": "Cody", "last_name": "Thompson", "email": "nathanneal@example.net", "phone_number": "001-942-937-5289x265", "passport_number": "D49070192", "nationality": "Lithuania"}
# Key: None, Value: {"customer_id": 27, "first_name": "Sandra", "last_name": "Martin", "email": "cindy84@example.org", "phone_number": "550.400.1199", "passport_number": "564091880", "nationality": "China"}
# Key: None, Value: {"customer_id": 28, "first_name": "Jose", "last_name": "Lynch", "email": "gonzalezkerry@example.net", "phone_number": "8826288338", "passport_number": "172427291", "nationality": "Micronesia"}
# Key: None, Value: {"customer_id": 29, "first_name": "James", "last_name": "Jacobs", "email": "tnguyen@example.net", "phone_number": "(700)775-3994", "passport_number": "F90239060", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 30, "first_name": "Brent", "last_name": "Turner", "email": "garrettramirez@example.org", "phone_number": "234.617.0482x81759", "passport_number": "M49216559", "nationality": "Northern Mariana Islands"}
# Key: None, Value: {"customer_id": 31, "first_name": "Brian", "last_name": "Smith", "email": "sarahgiles@example.net", "phone_number": "001-419-422-3445x362", "passport_number": "E52698729", "nationality": "Uzbekistan"}
# Key: None, Value: {"customer_id": 32, "first_name": "Donna", "last_name": "Thompson", "email": "kwilliams@example.net", "phone_number": "001-228-945-1206", "passport_number": "098128891", "nationality": "French Polynesia"}
# Key: None, Value: {"customer_id": 33, "first_name": "Samuel", "last_name": "Bentley", "email": "jason01@example.com", "phone_number": "327-742-7943x146", "passport_number": "M65182106", "nationality": "New Caledonia"}
# Key: None, Value: {"customer_id": 34, "first_name": "Latoya", "last_name": "Parker", "email": "erice@example.org", "phone_number": "2242151410", "passport_number": "075574713", "nationality": "Slovenia"}
# Key: None, Value: {"customer_id": 35, "first_name": "Veronica", "last_name": "Tyler", "email": "jacqueline88@example.org", "phone_number": "581.455.9502", "passport_number": "299089240", "nationality": "Mexico"}
# Key: None, Value: {"customer_id": 36, "first_name": "Richard", "last_name": "Clark", "email": "tina24@example.com", "phone_number": "373-676-2544", "passport_number": "U32746228", "nationality": "Montenegro"}
# Key: None, Value: {"customer_id": 37, "first_name": "John", "last_name": "Parker", "email": "psanders@example.org", "phone_number": "559.777.5261x8849", "passport_number": "K03353737", "nationality": "Egypt"}
# Key: None, Value: {"customer_id": 38, "first_name": "Shannon", "last_name": "Long", "email": "angelasanchez@example.net", "phone_number": "982-962-7374", "passport_number": "086840381", "nationality": "Latvia"}
# Key: None, Value: {"customer_id": 39, "first_name": "Barbara", "last_name": "Rosario", "email": "zlynch@example.net", "phone_number": "+1-335-543-7387", "passport_number": "A46972507", "nationality": "Senegal"}
# Key: None, Value: {"customer_id": 40, "first_name": "Tracy", "last_name": "Mcneil", "email": "ssavage@example.org", "phone_number": "373.268.5039x482", "passport_number": "168965672", "nationality": "Guyana"}
# Key: None, Value: {"customer_id": 41, "first_name": "Kaylee", "last_name": "Evans", "email": "timothy47@example.com", "phone_number": "313.412.9468x7376", "passport_number": "838583191", "nationality": "Cyprus"}
# Key: None, Value: {"customer_id": 42, "first_name": "Felicia", "last_name": "Anderson", "email": "joseph08@example.com", "phone_number": "344.384.1978", "passport_number": "C55797607", "nationality": "Jamaica"}
# Key: None, Value: {"customer_id": 43, "first_name": "Diane", "last_name": "Hernandez", "email": "melissawall@example.net", "phone_number": "551-213-2301x42399", "passport_number": "985256864", "nationality": "Tunisia"}
# Key: None, Value: {"customer_id": 44, "first_name": "Morgan", "last_name": "Johnson", "email": "kingmichael@example.net", "phone_number": "001-402-348-1298", "passport_number": "X71417812", "nationality": "Costa Rica"}
# Key: None, Value: {"customer_id": 45, "first_name": "Tyler", "last_name": "Franklin", "email": "johnstonryan@example.com", "phone_number": "907.732.3632x29837", "passport_number": "251614515", "nationality": "Monaco"}
# Key: None, Value: {"customer_id": 46, "first_name": "Adam", "last_name": "Torres", "email": "casey05@example.org", "phone_number": "001-623-314-0531x8538", "passport_number": "706616376", "nationality": "Sao Tome and Principe"}
# Key: None, Value: {"customer_id": 47, "first_name": "Allison", "last_name": "White", "email": "lauradecker@example.net", "phone_number": "611-978-4982", "passport_number": "163533728", "nationality": "Sudan"}
# Key: None, Value: {"customer_id": 48, "first_name": "Matthew", "last_name": "Buchanan", "email": "bennettpaul@example.com", "phone_number": "001-245-621-5774x668", "passport_number": "201924203", "nationality": "Brunei Darussalam"}
# Key: None, Value: {"customer_id": 49, "first_name": "Amber", "last_name": "Estrada", "email": "mark35@example.com", "phone_number": "659-559-1610x44280", "passport_number": "785666942", "nationality": "Korea"}
# Key: None, Value: {"customer_id": 50, "first_name": "Thomas", "last_name": "Phillips", "email": "johnbailey@example.org", "phone_number": "278-885-9860x9963", "passport_number": "E24305252", "nationality": "Slovakia (Slovak Republic)"}
# Key: None, Value: {"customer_id": 51, "first_name": "Sara", "last_name": "Hunter", "email": "tuckerdavid@example.net", "phone_number": "8308144746", "passport_number": "594867528", "nationality": "Mozambique"}
# Key: None, Value: {"customer_id": 52, "first_name": "Steven", "last_name": "Clark", "email": "baldwinchris@example.org", "phone_number": "(808)432-0833x703", "passport_number": "807206805", "nationality": "Fiji"}
# Key: None, Value: {"customer_id": 53, "first_name": "Michael", "last_name": "Fisher", "email": "jessica00@example.org", "phone_number": "001-351-897-7847x02676", "passport_number": "Y26492099", "nationality": "Bangladesh"}
# Key: None, Value: {"customer_id": 54, "first_name": "Jonathon", "last_name": "Nguyen", "email": "umurphy@example.com", "phone_number": "001-597-635-4491", "passport_number": "737665178", "nationality": "Liechtenstein"}
# Key: None, Value: {"customer_id": 55, "first_name": "Barbara", "last_name": "Owens", "email": "vobrien@example.org", "phone_number": "001-342-373-9013x8592", "passport_number": "021080703", "nationality": "Aruba"}
# Key: None, Value: {"customer_id": 56, "first_name": "Ashlee", "last_name": "Francis", "email": "kimberly27@example.org", "phone_number": "+1-832-819-2708x9547", "passport_number": "M43903770", "nationality": "Guinea-Bissau"}
# Key: None, Value: {"customer_id": 57, "first_name": "Jeremy", "last_name": "Davies", "email": "rodriguezsusan@example.com", "phone_number": "001-373-554-8520", "passport_number": "T17404325", "nationality": "Italy"}
# Key: None, Value: {"customer_id": 58, "first_name": "Patrick", "last_name": "Davis", "email": "gregoryfuller@example.net", "phone_number": "767-942-7068", "passport_number": "127616435", "nationality": "Puerto Rico"}
# Key: None, Value: {"customer_id": 59, "first_name": "Ian", "last_name": "Merritt", "email": "mjohnson@example.net", "phone_number": "+1-528-716-1741x664", "passport_number": "F12207702", "nationality": "Zimbabwe"}
# Key: None, Value: {"customer_id": 60, "first_name": "Amanda", "last_name": "Adams", "email": "pelliott@example.com", "phone_number": "4936257818", "passport_number": "C83446599", "nationality": "Guadeloupe"}
# Key: None, Value: {"customer_id": 61, "first_name": "Mark", "last_name": "Lopez", "email": "kochamanda@example.net", "phone_number": "(212)904-4025x5538", "passport_number": "E36191966", "nationality": "Bosnia and Herzegovina"}
# Key: None, Value: {"customer_id": 62, "first_name": "Donna", "last_name": "Collins", "email": "lmeyer@example.org", "phone_number": "2858550163", "passport_number": "N36756158", "nationality": "Vietnam"}
# Key: None, Value: {"customer_id": 63, "first_name": "Julie", "last_name": "Johnson", "email": "spalmer@example.com", "phone_number": "+1-470-215-4728x016", "passport_number": "R05283815", "nationality": "Indonesia"}
# Key: None, Value: {"customer_id": 64, "first_name": "Francisco", "last_name": "Campbell", "email": "raymond95@example.net", "phone_number": "542-706-5752x213", "passport_number": "L35253016", "nationality": "Montserrat"}
# Key: None, Value: {"customer_id": 65, "first_name": "Tyler", "last_name": "Dixon", "email": "christinamoreno@example.com", "phone_number": "8822542183", "passport_number": "806869208", "nationality": "Senegal"}
# Key: None, Value: {"customer_id": 66, "first_name": "Eric", "last_name": "Murphy", "email": "leemarcus@example.com", "phone_number": "(811)611-2218x462", "passport_number": "X00471895", "nationality": "Niue"}
# Key: None, Value: {"customer_id": 67, "first_name": "Kenneth", "last_name": "White", "email": "calvin62@example.com", "phone_number": "+1-972-890-0155", "passport_number": "S45995135", "nationality": "Canada"}
# Key: None, Value: {"customer_id": 68, "first_name": "Rachel", "last_name": "Scott", "email": "morgan48@example.com", "phone_number": "(828)399-3557x7205", "passport_number": "P57424270", "nationality": "Cape Verde"}
# Key: None, Value: {"customer_id": 69, "first_name": "Travis", "last_name": "Smith", "email": "douglasbarker@example.net", "phone_number": "774-945-7832x56826", "passport_number": "P69122714", "nationality": "Reunion"}
# Key: None, Value: {"customer_id": 70, "first_name": "Scott", "last_name": "Rose", "email": "wilsontammy@example.com", "phone_number": "971-502-0907x7360", "passport_number": "X75568144", "nationality": "Paraguay"}
# Key: None, Value: {"customer_id": 71, "first_name": "Katie", "last_name": "Wilson", "email": "jeffrey40@example.net", "phone_number": "352-530-8751x75649", "passport_number": "U29331448", "nationality": "Svalbard & Jan Mayen Islands"}
# Key: None, Value: {"customer_id": 72, "first_name": "Rebecca", "last_name": "Johnson", "email": "lesterjill@example.net", "phone_number": "3677483444", "passport_number": "512428281", "nationality": "Andorra"}
# Key: None, Value: {"customer_id": 73, "first_name": "Lisa", "last_name": "Haas", "email": "jimmyortiz@example.net", "phone_number": "+1-419-553-3667x2678", "passport_number": "167874678", "nationality": "British Indian Ocean Territory (Chagos Archipelago)"}
# Key: None, Value: {"customer_id": 74, "first_name": "Penny", "last_name": "Mendez", "email": "brianvega@example.net", "phone_number": "(635)776-0088x21833", "passport_number": "I76204839", "nationality": "Uganda"}
# Key: None, Value: {"customer_id": 75, "first_name": "Stephen", "last_name": "Henderson", "email": "michelleshort@example.org", "phone_number": "001-237-761-6746", "passport_number": "189245351", "nationality": "Isle of Man"}
# Key: None, Value: {"customer_id": 76, "first_name": "Steven", "last_name": "Johnson", "email": "jeremylewis@example.org", "phone_number": "830-518-6797x3945", "passport_number": "317505154", "nationality": "Tokelau"}
# Key: None, Value: {"customer_id": 77, "first_name": "Chris", "last_name": "Hill", "email": "jodirichardson@example.net", "phone_number": "866.409.1092", "passport_number": "J92883175", "nationality": "Moldova"}
# Key: None, Value: {"customer_id": 78, "first_name": "Randy", "last_name": "Quinn", "email": "goodwinbarbara@example.com", "phone_number": "277.300.6477x5972", "passport_number": "430164406", "nationality": "Burkina Faso"}
# Key: None, Value: {"customer_id": 79, "first_name": "Carlos", "last_name": "Hunt", "email": "johnsonlisa@example.org", "phone_number": "948.595.4524", "passport_number": "G64799707", "nationality": "Cook Islands"}
# Key: None, Value: {"customer_id": 80, "first_name": "Taylor", "last_name": "Cooley", "email": "desireesmith@example.org", "phone_number": "001-418-989-4334", "passport_number": "F58544227", "nationality": "Saint Martin"}
# Key: None, Value: {"customer_id": 81, "first_name": "Jessica", "last_name": "Jackson", "email": "dtran@example.com", "phone_number": "001-621-907-5588x92168", "passport_number": "I08945357", "nationality": "Taiwan"}
# Key: None, Value: {"customer_id": 82, "first_name": "Jacqueline", "last_name": "Keller", "email": "leonardkaren@example.org", "phone_number": "304-979-1229x19842", "passport_number": "B71465827", "nationality": "Tunisia"}
# Key: None, Value: {"customer_id": 83, "first_name": "Randy", "last_name": "Barnes", "email": "zellis@example.net", "phone_number": "+1-588-224-1291x0296", "passport_number": "630406933", "nationality": "Jordan"}
# Key: None, Value: {"customer_id": 84, "first_name": "Johnny", "last_name": "Sutton", "email": "wnicholson@example.net", "phone_number": "815-652-6902x6985", "passport_number": "O84069700", "nationality": "Isle of Man"}
# Key: None, Value: {"customer_id": 85, "first_name": "Zoe", "last_name": "Sims", "email": "acrawford@example.org", "phone_number": "652-796-7297x23632", "passport_number": "013133187", "nationality": "Congo"}
# Key: None, Value: {"customer_id": 86, "first_name": "Randall", "last_name": "Brown", "email": "hallrickey@example.com", "phone_number": "465.406.5045", "passport_number": "056278002", "nationality": "Vietnam"}
# Key: None, Value: {"customer_id": 87, "first_name": "Alyssa", "last_name": "Brown", "email": "joann24@example.net", "phone_number": "+1-984-509-8359x69628", "passport_number": "A80163234", "nationality": "Portugal"}
# Key: None, Value: {"customer_id": 88, "first_name": "Matthew", "last_name": "Lutz", "email": "sarahjackson@example.com", "phone_number": "001-688-625-2295x4010", "passport_number": "410982704", "nationality": "Guinea"}
# Key: None, Value: {"customer_id": 89, "first_name": "William", "last_name": "Blankenship", "email": "juangarcia@example.org", "phone_number": "744.882.2917x353", "passport_number": "321844520", "nationality": "Bhutan"}
# Key: None, Value: {"customer_id": 90, "first_name": "Andrew", "last_name": "Fowler", "email": "choidaryl@example.com", "phone_number": "001-411-406-3119x8395", "passport_number": "716240111", "nationality": "Costa Rica"}
# Key: None, Value: {"customer_id": 91, "first_name": "Brett", "last_name": "Vasquez", "email": "tannerwagner@example.net", "phone_number": "(619)870-9464x81772", "passport_number": "L75890808", "nationality": "Korea"}
# Key: None, Value: {"customer_id": 92, "first_name": "Laura", "last_name": "Brown", "email": "sierra72@example.com", "phone_number": "9129525180", "passport_number": "728130056", "nationality": "Jamaica"}
# Key: None, Value: {"customer_id": 93, "first_name": "Danielle", "last_name": "Lopez", "email": "reyescory@example.org", "phone_number": "313-367-4999", "passport_number": "679684035", "nationality": "French Guiana"}
# Key: None, Value: {"customer_id": 94, "first_name": "Scott", "last_name": "Wright", "email": "nelsonadam@example.com", "phone_number": "6897079186", "passport_number": "Z96794952", "nationality": "Italy"}
# Key: None, Value: {"customer_id": 95, "first_name": "Misty", "last_name": "Mills", "email": "lnguyen@example.com", "phone_number": "+1-231-775-2252", "passport_number": "703032010", "nationality": "Luxembourg"}
# Key: None, Value: {"customer_id": 96, "first_name": "Brandon", "last_name": "Castillo", "email": "joel45@example.org", "phone_number": "+1-684-415-9128x71396", "passport_number": "423433498", "nationality": "Kenya"}
# Key: None, Value: {"customer_id": 97, "first_name": "Matthew", "last_name": "Boyd", "email": "joel56@example.org", "phone_number": "319-551-7490x91747", "passport_number": "G43360689", "nationality": "Brunei Darussalam"}
# Key: None, Value: {"customer_id": 98, "first_name": "Scott", "last_name": "Richard", "email": "brianpoole@example.org", "phone_number": "+1-569-947-9981x28619", "passport_number": "O50686494", "nationality": "Syrian Arab Republic"}
# Key: None, Value: {"customer_id": 99, "first_name": "Aaron", "last_name": "Lopez", "email": "bennettelizabeth@example.com", "phone_number": "+1-748-276-8595x2867", "passport_number": "458154512", "nationality": "Myanmar"}
# Key: None, Value: {"customer_id": 100, "first_name": "Timothy", "last_name": "Larsen", "email": "ghart@example.org", "phone_number": "(732)965-7387x70741", "passport_number": "661158484", "nationality": "Saint Kitts and Nevis"}
# Key: None, Value: {"customer_id": 101, "first_name": "Hannah", "last_name": "Christensen", "email": "uboyer@example.net", "phone_number": "837.688.5983x776", "passport_number": "C02541221", "nationality": "Hungary"}
# Key: None, Value: {"customer_id": 102, "first_name": "James", "last_name": "Warren", "email": "jodidennis@example.org", "phone_number": "779-333-1580x8932", "passport_number": "Z23438454", "nationality": "Pitcairn Islands"}
# Key: None, Value: {"customer_id": 103, "first_name": "Joseph", "last_name": "Davis", "email": "brandon17@example.net", "phone_number": "001-602-909-7648x6012", "passport_number": "J67318091", "nationality": "Lebanon"}
# Key: None, Value: {"customer_id": 104, "first_name": "James", "last_name": "Macias", "email": "anna80@example.com", "phone_number": "(737)420-7535x817", "passport_number": "H52506968", "nationality": "Moldova"}
# Key: None, Value: {"customer_id": 105, "first_name": "Jennifer", "last_name": "Peterson", "email": "william57@example.net", "phone_number": "7287738919", "passport_number": "038524787", "nationality": "Jordan"}
# Key: None, Value: {"customer_id": 106, "first_name": "Wyatt", "last_name": "Blake", "email": "stephaniesanchez@example.com", "phone_number": "(713)982-0226", "passport_number": "298862774", "nationality": "Brazil"}
# Key: None, Value: {"customer_id": 107, "first_name": "Christopher", "last_name": "Ryan", "email": "wespinoza@example.net", "phone_number": "466-941-2044", "passport_number": "607878181", "nationality": "Cameroon"}
# Key: None, Value: {"customer_id": 108, "first_name": "Sabrina", "last_name": "Reyes", "email": "jordandaniel@example.net", "phone_number": "328.227.9586", "passport_number": "210903793", "nationality": "Djibouti"}
# Key: None, Value: {"customer_id": 109, "first_name": "April", "last_name": "Pittman", "email": "richardsantiago@example.org", "phone_number": "(461)300-9763", "passport_number": "P53987774", "nationality": "Madagascar"}
# Key: None, Value: {"customer_id": 110, "first_name": "Brandon", "last_name": "Smith", "email": "schaeferricky@example.net", "phone_number": "674.474.8359x370", "passport_number": "510117111", "nationality": "Uruguay"}
# Key: None, Value: {"customer_id": 111, "first_name": "Kyle", "last_name": "Martin", "email": "bmartin@example.com", "phone_number": "001-321-321-1738x8241", "passport_number": "L57435653", "nationality": "Niue"}
# Key: None, Value: {"customer_id": 112, "first_name": "Edward", "last_name": "Hernandez", "email": "dbaldwin@example.org", "phone_number": "713-532-1892x0752", "passport_number": "324521775", "nationality": "Equatorial Guinea"}
# Key: None, Value: {"customer_id": 113, "first_name": "Selena", "last_name": "Huber", "email": "portersheila@example.org", "phone_number": "+1-363-889-2890", "passport_number": "Z00908624", "nationality": "Solomon Islands"}
# Key: None, Value: {"customer_id": 114, "first_name": "Daniel", "last_name": "Mccarty", "email": "carla82@example.org", "phone_number": "4107466279", "passport_number": "E16930673", "nationality": "Malaysia"}
# Key: None, Value: {"customer_id": 115, "first_name": "William", "last_name": "Khan", "email": "vmosley@example.net", "phone_number": "893-940-6400", "passport_number": "238438758", "nationality": "Lao People's Democratic Republic"}
# Key: None, Value: {"customer_id": 116, "first_name": "Eric", "last_name": "Campbell", "email": "nicolemitchell@example.com", "phone_number": "290-238-6403x06796", "passport_number": "K11711480", "nationality": "Burkina Faso"}
# Key: None, Value: {"customer_id": 117, "first_name": "Kyle", "last_name": "Brown", "email": "sandra85@example.com", "phone_number": "312-349-0594x508", "passport_number": "311688907", "nationality": "Malawi"}
# Key: None, Value: {"customer_id": 118, "first_name": "Steven", "last_name": "Romero", "email": "nmontgomery@example.net", "phone_number": "(695)661-5830", "passport_number": "P56581778", "nationality": "Maldives"}
# Key: None, Value: {"customer_id": 119, "first_name": "Emily", "last_name": "Henderson", "email": "christopher27@example.com", "phone_number": "001-249-795-4426x8743", "passport_number": "442287447", "nationality": "India"}
# Key: None, Value: {"customer_id": 120, "first_name": "Derek", "last_name": "Rodriguez", "email": "johnsonjohn@example.com", "phone_number": "+1-414-546-4697", "passport_number": "B66914322", "nationality": "Saint Helena"}
# Key: None, Value: {"customer_id": 121, "first_name": "Erika", "last_name": "Smith", "email": "jessevasquez@example.org", "phone_number": "933-252-0852x652", "passport_number": "N38647851", "nationality": "Saint Lucia"}
# Key: None, Value: {"customer_id": 122, "first_name": "Kevin", "last_name": "Jacobson", "email": "michael38@example.com", "phone_number": "4147282184", "passport_number": "O12167158", "nationality": "Cambodia"}
# Key: None, Value: {"customer_id": 123, "first_name": "Karen", "last_name": "Bryan", "email": "hartcurtis@example.org", "phone_number": "001-917-995-5495x25661", "passport_number": "C30602426", "nationality": "British Indian Ocean Territory (Chagos Archipelago)"}
# Key: None, Value: {"customer_id": 124, "first_name": "Dawn", "last_name": "White", "email": "michaelphillips@example.com", "phone_number": "001-407-522-1471x29819", "passport_number": "O74591198", "nationality": "Mozambique"}
# Key: None, Value: {"customer_id": 125, "first_name": "Joseph", "last_name": "Vargas", "email": "manngreg@example.net", "phone_number": "+1-981-977-0687x18328", "passport_number": "P82651990", "nationality": "Mongolia"}
# Key: None, Value: {"customer_id": 126, "first_name": "Seth", "last_name": "Fisher", "email": "vhull@example.org", "phone_number": "(704)323-6396", "passport_number": "J76349880", "nationality": "Canada"}
# Key: None, Value: {"customer_id": 127, "first_name": "Daniel", "last_name": "Smith", "email": "lejoseph@example.com", "phone_number": "854.448.3751", "passport_number": "Y88233838", "nationality": "Martinique"}
# Key: None, Value: {"customer_id": 128, "first_name": "Russell", "last_name": "Alexander", "email": "nicolefrench@example.net", "phone_number": "437-257-3940", "passport_number": "W38759828", "nationality": "Nicaragua"}
# Key: None, Value: {"customer_id": 129, "first_name": "Michael", "last_name": "Williams", "email": "michelle65@example.net", "phone_number": "(969)691-4466", "passport_number": "F13718363", "nationality": "Brunei Darussalam"}
# Key: None, Value: {"customer_id": 130, "first_name": "Sandy", "last_name": "Pineda", "email": "fhernandez@example.net", "phone_number": "687-661-7090x846", "passport_number": "279827685", "nationality": "Togo"}
# Key: None, Value: {"customer_id": 131, "first_name": "Gary", "last_name": "Griffin", "email": "uanthony@example.net", "phone_number": "401-578-7713x4188", "passport_number": "135694745", "nationality": "Sierra Leone"}
# Key: None, Value: {"customer_id": 132, "first_name": "Brandon", "last_name": "Brown", "email": "jill83@example.net", "phone_number": "786-361-6111x8237", "passport_number": "J72488699", "nationality": "Algeria"}
# Key: None, Value: {"customer_id": 133, "first_name": "Melissa", "last_name": "Case", "email": "jcastaneda@example.org", "phone_number": "824.368.9090x1183", "passport_number": "N57124434", "nationality": "Saudi Arabia"}
# Key: None, Value: {"customer_id": 134, "first_name": "Brenda", "last_name": "Barker", "email": "jason79@example.net", "phone_number": "969.260.8101", "passport_number": "377190714", "nationality": "Mexico"}
# Key: None, Value: {"customer_id": 135, "first_name": "Jennifer", "last_name": "Barnes", "email": "allisonfreeman@example.org", "phone_number": "7497674775", "passport_number": "H40674192", "nationality": "Ghana"}
# Key: None, Value: {"customer_id": 136, "first_name": "Kim", "last_name": "Gardner", "email": "collinsdaniel@example.org", "phone_number": "001-263-365-2344x01833", "passport_number": "H92365212", "nationality": "Qatar"}
# Key: None, Value: {"customer_id": 137, "first_name": "Sonya", "last_name": "Cohen", "email": "iluna@example.com", "phone_number": "001-498-216-8907x042", "passport_number": "I57710637", "nationality": "Oman"}
# Key: None, Value: {"customer_id": 138, "first_name": "Richard", "last_name": "Key", "email": "bonniewhitney@example.net", "phone_number": "001-988-948-9721x441", "passport_number": "P61662018", "nationality": "American Samoa"}
# Key: None, Value: {"customer_id": 139, "first_name": "Michael", "last_name": "Myers", "email": "amy70@example.org", "phone_number": "001-298-505-4515x741", "passport_number": "B70917191", "nationality": "Guyana"}
# Key: None, Value: {"customer_id": 140, "first_name": "Dominic", "last_name": "Morgan", "email": "katherineking@example.org", "phone_number": "962-459-7741", "passport_number": "M61504064", "nationality": "Central African Republic"}
# Key: None, Value: {"customer_id": 141, "first_name": "Fred", "last_name": "Olson", "email": "colleenbryant@example.com", "phone_number": "(544)771-9028", "passport_number": "W47701125", "nationality": "North Macedonia"}
# Key: None, Value: {"customer_id": 142, "first_name": "Mark", "last_name": "Taylor", "email": "bookerashley@example.org", "phone_number": "439.239.1578", "passport_number": "N56199619", "nationality": "Cote d'Ivoire"}
# Key: None, Value: {"customer_id": 143, "first_name": "Erin", "last_name": "Martin", "email": "wlewis@example.org", "phone_number": "+1-455-271-4964", "passport_number": "T68239988", "nationality": "Lithuania"}
# Key: None, Value: {"customer_id": 144, "first_name": "Ernest", "last_name": "Sloan", "email": "adambarr@example.org", "phone_number": "(888)632-2112x4307", "passport_number": "Y13709414", "nationality": "Tanzania"}
# Key: None, Value: {"customer_id": 145, "first_name": "Nancy", "last_name": "Caldwell", "email": "leah70@example.org", "phone_number": "305-348-6062x24816", "passport_number": "A15661009", "nationality": "Albania"}
# Key: None, Value: {"customer_id": 146, "first_name": "Steven", "last_name": "Lee", "email": "munozmichael@example.net", "phone_number": "597.820.1465x656", "passport_number": "917674013", "nationality": "Fiji"}
# Key: None, Value: {"customer_id": 147, "first_name": "Heidi", "last_name": "Koch", "email": "julie19@example.com", "phone_number": "574-427-0293x84456", "passport_number": "991730971", "nationality": "Faroe Islands"}
# Key: None, Value: {"customer_id": 148, "first_name": "Ronald", "last_name": "Mcgee", "email": "spencerlauren@example.org", "phone_number": "9275238943", "passport_number": "C53608903", "nationality": "Bolivia"}
# Key: None, Value: {"customer_id": 149, "first_name": "April", "last_name": "Johnston", "email": "brenda97@example.com", "phone_number": "(912)955-0974x8191", "passport_number": "X47073595", "nationality": "Poland"}
# Key: None, Value: {"customer_id": 150, "first_name": "Tonya", "last_name": "Mitchell", "email": "delgadojennifer@example.com", "phone_number": "(637)362-7547", "passport_number": "751428448", "nationality": "Bahrain"}
# Key: None, Value: {"customer_id": 151, "first_name": "Erin", "last_name": "Livingston", "email": "browncharles@example.org", "phone_number": "(938)334-1422x687", "passport_number": "864731414", "nationality": "Sierra Leone"}
# Key: None, Value: {"customer_id": 152, "first_name": "Madison", "last_name": "Stewart", "email": "nsanchez@example.com", "phone_number": "001-918-566-2747x99973", "passport_number": "K77351215", "nationality": "Sweden"}
# Key: None, Value: {"customer_id": 153, "first_name": "Dwayne", "last_name": "Henderson", "email": "carolalexander@example.com", "phone_number": "503.848.0883", "passport_number": "339838282", "nationality": "Brunei Darussalam"}
# Key: None, Value: {"customer_id": 154, "first_name": "Mary", "last_name": "Harvey", "email": "esweeney@example.net", "phone_number": "(752)835-4036", "passport_number": "V08899772", "nationality": "Somalia"}
# Key: None, Value: {"customer_id": 155, "first_name": "Louis", "last_name": "Thomas", "email": "sanchezhannah@example.com", "phone_number": "484.774.0854x86007", "passport_number": "325422715", "nationality": "Cambodia"}
# Key: None, Value: {"customer_id": 156, "first_name": "Amy", "last_name": "Moss", "email": "hernandezbradley@example.com", "phone_number": "927.406.2189x6822", "passport_number": "229704814", "nationality": "Spain"}
# Key: None, Value: {"customer_id": 157, "first_name": "Darlene", "last_name": "Jackson", "email": "thomasann@example.net", "phone_number": "649-455-3238", "passport_number": "F72012863", "nationality": "Tajikistan"}
# Key: None, Value: {"customer_id": 158, "first_name": "Amanda", "last_name": "Maldonado", "email": "daniel20@example.net", "phone_number": "001-719-751-7395x241", "passport_number": "756200864", "nationality": "Kazakhstan"}
# Key: None, Value: {"customer_id": 159, "first_name": "Angela", "last_name": "Dixon", "email": "tcummings@example.net", "phone_number": "(584)684-5466x67406", "passport_number": "269419713", "nationality": "Burundi"}
# Key: None, Value: {"customer_id": 160, "first_name": "Corey", "last_name": "Robinson", "email": "nsanchez@example.com", "phone_number": "727.749.9484x73323", "passport_number": "J90166330", "nationality": "Sri Lanka"}
# Key: None, Value: {"customer_id": 161, "first_name": "Timothy", "last_name": "Rivers", "email": "jeremyhernandez@example.com", "phone_number": "3498851108", "passport_number": "S55205086", "nationality": "Belarus"}
# Key: None, Value: {"customer_id": 162, "first_name": "Rachel", "last_name": "Liu", "email": "christopher94@example.com", "phone_number": "+1-427-352-2901x6107", "passport_number": "V53879132", "nationality": "Albania"}
# Key: None, Value: {"customer_id": 163, "first_name": "Richard", "last_name": "Brooks", "email": "antonioavila@example.net", "phone_number": "652.203.0230", "passport_number": "H16570401", "nationality": "Togo"}
# Key: None, Value: {"customer_id": 164, "first_name": "Thomas", "last_name": "Rogers", "email": "pfrazier@example.net", "phone_number": "(550)743-7542x66464", "passport_number": "712762862", "nationality": "Belgium"}
# Key: None, Value: {"customer_id": 165, "first_name": "Anna", "last_name": "Brown", "email": "jenkinsmatthew@example.net", "phone_number": "+1-976-485-5713", "passport_number": "670712155", "nationality": "Germany"}
# Key: None, Value: {"customer_id": 166, "first_name": "Michael", "last_name": "Garcia", "email": "qhawkins@example.com", "phone_number": "3513272433", "passport_number": "R21566658", "nationality": "Slovenia"}
# Key: None, Value: {"customer_id": 167, "first_name": "Carolyn", "last_name": "Sims", "email": "ronald66@example.com", "phone_number": "001-701-754-1484", "passport_number": "O84445349", "nationality": "Korea"}
# Key: None, Value: {"customer_id": 168, "first_name": "Jeffrey", "last_name": "Gray", "email": "hillyolanda@example.net", "phone_number": "+1-670-682-3278x8718", "passport_number": "721216044", "nationality": "Jersey"}
# Key: None, Value: {"customer_id": 169, "first_name": "Tiffany", "last_name": "Fry", "email": "grossmegan@example.org", "phone_number": "001-730-454-2281x72312", "passport_number": "U40251482", "nationality": "Iran"}
# Key: None, Value: {"customer_id": 170, "first_name": "Anne", "last_name": "Smith", "email": "gonzaleslauren@example.net", "phone_number": "+1-707-724-1279", "passport_number": "X54965432", "nationality": "Saint Kitts and Nevis"}
# Key: None, Value: {"customer_id": 171, "first_name": "Joshua", "last_name": "Navarro", "email": "kramerrichard@example.org", "phone_number": "395.655.6127", "passport_number": "Z95184952", "nationality": "Barbados"}
# Key: None, Value: {"customer_id": 172, "first_name": "Laura", "last_name": "Owens", "email": "tabithajennings@example.com", "phone_number": "451.895.2881", "passport_number": "691549282", "nationality": "Albania"}
# Key: None, Value: {"customer_id": 173, "first_name": "Kelly", "last_name": "Dean", "email": "mortondavid@example.net", "phone_number": "3045107732", "passport_number": "O64553152", "nationality": "Seychelles"}
# Key: None, Value: {"customer_id": 174, "first_name": "Curtis", "last_name": "Garcia", "email": "jerryjones@example.net", "phone_number": "(813)721-3083", "passport_number": "I41406719", "nationality": "Israel"}
# Key: None, Value: {"customer_id": 175, "first_name": "Cindy", "last_name": "Rivera", "email": "kmaxwell@example.com", "phone_number": "9024300437", "passport_number": "B79460006", "nationality": "Italy"}
# Key: None, Value: {"customer_id": 176, "first_name": "Laura", "last_name": "Singleton", "email": "lmiles@example.net", "phone_number": "001-713-315-5244x52494", "passport_number": "U26171073", "nationality": "Denmark"}
# Key: None, Value: {"customer_id": 177, "first_name": "Tiffany", "last_name": "Torres", "email": "robersonjeffrey@example.com", "phone_number": "742.684.1925x793", "passport_number": "016191553", "nationality": "Tonga"}
# Key: None, Value: {"customer_id": 178, "first_name": "Taylor", "last_name": "Burton", "email": "hollyfisher@example.org", "phone_number": "+1-865-369-9795x457", "passport_number": "125803127", "nationality": "Eritrea"}
# Key: None, Value: {"customer_id": 179, "first_name": "Jennifer", "last_name": "Rocha", "email": "ggraham@example.net", "phone_number": "899.200.5454x4558", "passport_number": "178104840", "nationality": "Chile"}
# Key: None, Value: {"customer_id": 180, "first_name": "Ricardo", "last_name": "Ruiz", "email": "tjohnson@example.net", "phone_number": "001-234-240-8966x2243", "passport_number": "Y43417127", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 181, "first_name": "William", "last_name": "Norman", "email": "valenciadavid@example.com", "phone_number": "856.636.5569", "passport_number": "117244873", "nationality": "Czech Republic"}
# Key: None, Value: {"customer_id": 182, "first_name": "Matthew", "last_name": "Cox", "email": "mary61@example.net", "phone_number": "8638538462", "passport_number": "996496917", "nationality": "New Zealand"}
# Key: None, Value: {"customer_id": 183, "first_name": "Krystal", "last_name": "Hayes", "email": "zritter@example.net", "phone_number": "+1-769-596-5882x5943", "passport_number": "H01250992", "nationality": "Maldives"}
# Key: None, Value: {"customer_id": 184, "first_name": "Lisa", "last_name": "Rivera", "email": "anna93@example.com", "phone_number": "7426232766", "passport_number": "528433228", "nationality": "Belgium"}
# Key: None, Value: {"customer_id": 185, "first_name": "Yolanda", "last_name": "Moore", "email": "aimee98@example.net", "phone_number": "(974)750-1741x0210", "passport_number": "Z09255161", "nationality": "Solomon Islands"}
# Key: None, Value: {"customer_id": 186, "first_name": "Thomas", "last_name": "George", "email": "grahamhunter@example.org", "phone_number": "(288)236-2411", "passport_number": "465082815", "nationality": "Cocos (Keeling) Islands"}
# Key: None, Value: {"customer_id": 187, "first_name": "Sarah", "last_name": "Jordan", "email": "maria21@example.com", "phone_number": "(592)952-9550x7903", "passport_number": "635162055", "nationality": "Guinea-Bissau"}
# Key: None, Value: {"customer_id": 188, "first_name": "Alyssa", "last_name": "Sheppard", "email": "owhite@example.net", "phone_number": "850.269.8783", "passport_number": "Y20250669", "nationality": "United Kingdom"}
# Key: None, Value: {"customer_id": 189, "first_name": "Peggy", "last_name": "Marshall", "email": "ukim@example.com", "phone_number": "001-976-976-3121x07604", "passport_number": "065941947", "nationality": "Sierra Leone"}
# Key: None, Value: {"customer_id": 190, "first_name": "Angel", "last_name": "Raymond", "email": "hernandezjason@example.com", "phone_number": "+1-744-413-8355x79145", "passport_number": "468005747", "nationality": "Jamaica"}
# Key: None, Value: {"customer_id": 191, "first_name": "Sharon", "last_name": "Williams", "email": "rvaldez@example.net", "phone_number": "3835755215", "passport_number": "U39734292", "nationality": "Sudan"}
# Key: None, Value: {"customer_id": 192, "first_name": "Amanda", "last_name": "Hamilton", "email": "sstewart@example.org", "phone_number": "(730)871-8231", "passport_number": "949424709", "nationality": "Nauru"}
# Key: None, Value: {"customer_id": 193, "first_name": "Barbara", "last_name": "Wallace", "email": "qfarmer@example.net", "phone_number": "(725)525-0779x6518", "passport_number": "860099760", "nationality": "Lithuania"}
# Key: None, Value: {"customer_id": 194, "first_name": "Sandra", "last_name": "Cunningham", "email": "michaelholder@example.net", "phone_number": "286.346.3803x4210", "passport_number": "655736080", "nationality": "Trinidad and Tobago"}
# Key: None, Value: {"customer_id": 195, "first_name": "Walter", "last_name": "Ramirez", "email": "penamelanie@example.net", "phone_number": "(293)644-5160x263", "passport_number": "K13198946", "nationality": "Belarus"}
# Key: None, Value: {"customer_id": 196, "first_name": "Angela", "last_name": "Williams", "email": "martinvincent@example.net", "phone_number": "993-947-9656", "passport_number": "R73640177", "nationality": "Poland"}
# Key: None, Value: {"customer_id": 197, "first_name": "Robert", "last_name": "Thompson", "email": "oscarwalker@example.org", "phone_number": "(758)697-4978x2088", "passport_number": "437652753", "nationality": "Tuvalu"}
# Key: None, Value: {"customer_id": 198, "first_name": "Michael", "last_name": "Moore", "email": "ojones@example.com", "phone_number": "7904844737", "passport_number": "H95523818", "nationality": "South Georgia and the South Sandwich Islands"}
# Key: None, Value: {"customer_id": 199, "first_name": "Samuel", "last_name": "Morgan", "email": "rogerbrandt@example.org", "phone_number": "6169297763", "passport_number": "L31495994", "nationality": "Syrian Arab Republic"}
# Key: None, Value: {"customer_id": 200, "first_name": "Joseph", "last_name": "Greene", "email": "carolynedwards@example.net", "phone_number": "218-577-8205x755", "passport_number": "D67600310", "nationality": "Brunei Darussalam"}
# Key: None, Value: {"customer_id": 201, "first_name": "James", "last_name": "Nelson", "email": "butlermatthew@example.net", "phone_number": "001-494-463-5941x458", "passport_number": "649049267", "nationality": "Kiribati"}
# Key: None, Value: {"customer_id": 202, "first_name": "Scott", "last_name": "Cabrera", "email": "jfoster@example.com", "phone_number": "001-413-276-3407x8634", "passport_number": "Q69937108", "nationality": "Burkina Faso"}
# Key: None, Value: {"customer_id": 203, "first_name": "Carol", "last_name": "Patterson", "email": "moorenicole@example.net", "phone_number": "782.389.5600", "passport_number": "A65478979", "nationality": "Isle of Man"}
# Key: None, Value: {"customer_id": 204, "first_name": "Barbara", "last_name": "Cannon", "email": "davissarah@example.net", "phone_number": "(921)548-3426x835", "passport_number": "B46431662", "nationality": "Paraguay"}
# Key: None, Value: {"customer_id": 205, "first_name": "Sarah", "last_name": "Hicks", "email": "susan43@example.com", "phone_number": "4642305747", "passport_number": "L57103342", "nationality": "Colombia"}
# Key: None, Value: {"customer_id": 206, "first_name": "Michael", "last_name": "Barrett", "email": "jessica19@example.com", "phone_number": "001-965-835-1833x1109", "passport_number": "824769008", "nationality": "Oman"}
# Key: None, Value: {"customer_id": 207, "first_name": "Gary", "last_name": "Lindsey", "email": "gholmes@example.org", "phone_number": "001-780-487-1948", "passport_number": "I22045807", "nationality": "British Indian Ocean Territory (Chagos Archipelago)"}
# Key: None, Value: {"customer_id": 208, "first_name": "Jennifer", "last_name": "Taylor", "email": "bradleylarson@example.net", "phone_number": "973-647-3597x601", "passport_number": "780753387", "nationality": "Turkey"}
# Key: None, Value: {"customer_id": 209, "first_name": "John", "last_name": "Brown", "email": "awilson@example.net", "phone_number": "(535)811-1678", "passport_number": "Y96376694", "nationality": "Cambodia"}
# Key: None, Value: {"customer_id": 210, "first_name": "Willie", "last_name": "Gomez", "email": "urios@example.net", "phone_number": "813.919.4081", "passport_number": "Z08484388", "nationality": "United States Virgin Islands"}
# Key: None, Value: {"customer_id": 211, "first_name": "David", "last_name": "Thornton", "email": "carlosprice@example.com", "phone_number": "+1-998-452-4793x996", "passport_number": "819010607", "nationality": "Myanmar"}
# Key: None, Value: {"customer_id": 212, "first_name": "Peter", "last_name": "Johnson", "email": "jeremy56@example.net", "phone_number": "643.867.3536x65898", "passport_number": "J66439747", "nationality": "Barbados"}
# Key: None, Value: {"customer_id": 213, "first_name": "Troy", "last_name": "Ward", "email": "hgarcia@example.com", "phone_number": "(352)419-4329x315", "passport_number": "M29776586", "nationality": "Macao"}
# Key: None, Value: {"customer_id": 214, "first_name": "Cheryl", "last_name": "Brown", "email": "joseph70@example.com", "phone_number": "(276)482-0034x55621", "passport_number": "712217345", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 215, "first_name": "Crystal", "last_name": "Hernandez", "email": "rodriguezbradley@example.com", "phone_number": "765-861-1398x8982", "passport_number": "J30119600", "nationality": "United Kingdom"}
# Key: None, Value: {"customer_id": 216, "first_name": "Stacy", "last_name": "Black", "email": "smithrandall@example.net", "phone_number": "873.979.8356x20001", "passport_number": "674227957", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 217, "first_name": "Richard", "last_name": "Calhoun", "email": "miguel84@example.org", "phone_number": "+1-565-375-9521x084", "passport_number": "062304749", "nationality": "Latvia"}
# Key: None, Value: {"customer_id": 218, "first_name": "Leslie", "last_name": "Dawson", "email": "susan33@example.org", "phone_number": "+1-224-326-6309x6996", "passport_number": "765912375", "nationality": "Holy See (Vatican City State)"}
# Key: None, Value: {"customer_id": 219, "first_name": "Peter", "last_name": "Warren", "email": "rcole@example.net", "phone_number": "564.564.1120x2356", "passport_number": "W87231722", "nationality": "Swaziland"}
# Key: None, Value: {"customer_id": 220, "first_name": "Matthew", "last_name": "Foster", "email": "pwalker@example.org", "phone_number": "001-203-719-9525x86129", "passport_number": "938400499", "nationality": "Honduras"}
# ...
# Key: None, Value: {"customer_id": 784, "first_name": "Holly", "last_name": "Odom", "email": "matthew77@example.net", "phone_number": "7838352223", "passport_number": "999415700", "nationality": "Mozambique"}
# Key: None, Value: {"customer_id": 785, "first_name": "Jon", "last_name": "Perkins", "email": "ztucker@example.org", "phone_number": "(970)532-7349x9626", "passport_number": "M15722635", "nationality": "Botswana"}
# Key: None, Value: {"customer_id": 786, "first_name": "Jennifer", "last_name": "Herman", "email": "melissa70@example.net", "phone_number": "001-674-860-5393x3524", "passport_number": "495610718", "nationality": "Taiwan"}
# Key: None, Value: {"customer_id": 787, "first_name": "Michele", "last_name": "Hill", "email": "jenniferbrown@example.net", "phone_number": "001-390-599-5414", "passport_number": "017815652", "nationality": "Syrian Arab Republic"}
# Key: None, Value: {"customer_id": 788, "first_name": "Elizabeth", "last_name": "Lee", "email": "catherineturner@example.org", "phone_number": "001-473-839-1031x738", "passport_number": "319544291", "nationality": "Anguilla"}
# Key: None, Value: {"customer_id": 789, "first_name": "Amanda", "last_name": "Jackson", "email": "sean56@example.net", "phone_number": "256-591-3563x13107", "passport_number": "775248385", "nationality": "Tuvalu"}
# Key: None, Value: {"customer_id": 790, "first_name": "Susan", "last_name": "Stewart", "email": "dennisrodgers@example.com", "phone_number": "+1-527-980-8005x7022", "passport_number": "A42441835", "nationality": "Uzbekistan"}
# Key: None, Value: {"customer_id": 791, "first_name": "Jacob", "last_name": "Howard", "email": "justinsimpson@example.net", "phone_number": "533.888.7716", "passport_number": "M42192724", "nationality": "Micronesia"}
# Key: None, Value: {"customer_id": 792, "first_name": "Gregory", "last_name": "Black", "email": "christinawyatt@example.net", "phone_number": "650.338.4895", "passport_number": "A74475555", "nationality": "Kyrgyz Republic"}
# Key: None, Value: {"customer_id": 793, "first_name": "Frank", "last_name": "Lambert", "email": "acastro@example.net", "phone_number": "771-928-6860", "passport_number": "919494692", "nationality": "Belgium"}
# Key: None, Value: {"customer_id": 794, "first_name": "Lori", "last_name": "Rivera", "email": "zprice@example.com", "phone_number": "363-847-4906x49286", "passport_number": "209610768", "nationality": "Israel"}
# Key: None, Value: {"customer_id": 795, "first_name": "Joseph", "last_name": "Malone", "email": "qhernandez@example.org", "phone_number": "001-812-515-4626x3543", "passport_number": "F30090844", "nationality": "Papua New Guinea"}
# Key: None, Value: {"customer_id": 796, "first_name": "Robert", "last_name": "White", "email": "johnsonvirginia@example.org", "phone_number": "+1-532-948-4392x2813", "passport_number": "H50216695", "nationality": "Martinique"}
# Key: None, Value: {"customer_id": 797, "first_name": "Heather", "last_name": "Gonzalez", "email": "barkerjacqueline@example.com", "phone_number": "503.307.2956x527", "passport_number": "C52598343", "nationality": "Cameroon"}
# Key: None, Value: {"customer_id": 798, "first_name": "Sarah", "last_name": "French", "email": "rmartinez@example.org", "phone_number": "001-810-439-2701x837", "passport_number": "613942236", "nationality": "Moldova"}
# Key: None, Value: {"customer_id": 799, "first_name": "Paul", "last_name": "Moore", "email": "uchapman@example.net", "phone_number": "001-942-401-2794x65604", "passport_number": "T94659404", "nationality": "Benin"}
# Key: None, Value: {"customer_id": 800, "first_name": "Mary", "last_name": "Rios", "email": "lisa22@example.com", "phone_number": "742.952.1065x3175", "passport_number": "M38377287", "nationality": "Syrian Arab Republic"}
# Key: None, Value: {"customer_id": 801, "first_name": "Robin", "last_name": "Hicks", "email": "rodriguezmelissa@example.com", "phone_number": "+1-613-478-3631", "passport_number": "181534828", "nationality": "Sudan"}
# Key: None, Value: {"customer_id": 802, "first_name": "Brooke", "last_name": "Garcia", "email": "changrachel@example.net", "phone_number": "+1-532-671-3081x15539", "passport_number": "285597246", "nationality": "Sao Tome and Principe"}
# Key: None, Value: {"customer_id": 803, "first_name": "Mary", "last_name": "Hall", "email": "jbaird@example.org", "phone_number": "713-658-4294x118", "passport_number": "Z73709168", "nationality": "Anguilla"}
# Key: None, Value: {"customer_id": 804, "first_name": "Tina", "last_name": "Bowers", "email": "glenntaylor@example.net", "phone_number": "(636)745-5376x392", "passport_number": "717063754", "nationality": "Saudi Arabia"}
# Key: None, Value: {"customer_id": 805, "first_name": "Sarah", "last_name": "Clark", "email": "sloandebbie@example.org", "phone_number": "001-810-925-9988x578", "passport_number": "976410234", "nationality": "Turkmenistan"}
# Key: None, Value: {"customer_id": 806, "first_name": "Christine", "last_name": "Stout", "email": "gcrawford@example.org", "phone_number": "5436401150", "passport_number": "D79072523", "nationality": "Nicaragua"}
# Key: None, Value: {"customer_id": 807, "first_name": "Holly", "last_name": "Smith", "email": "jonathan32@example.net", "phone_number": "+1-348-402-5981x43333", "passport_number": "Y86665352", "nationality": "Mali"}
# Key: None, Value: {"customer_id": 808, "first_name": "Katie", "last_name": "Chen", "email": "dfranklin@example.net", "phone_number": "(601)308-8575", "passport_number": "F69918830", "nationality": "Kyrgyz Republic"}
# Key: None, Value: {"customer_id": 809, "first_name": "Victor", "last_name": "Greene", "email": "fcrosby@example.com", "phone_number": "707.667.1967", "passport_number": "414149607", "nationality": "Bangladesh"}
# Key: None, Value: {"customer_id": 810, "first_name": "Sarah", "last_name": "Perez", "email": "williamschristina@example.com", "phone_number": "001-963-546-9677x45492", "passport_number": "177039947", "nationality": "Saint Kitts and Nevis"}
# Key: None, Value: {"customer_id": 811, "first_name": "Sandra", "last_name": "George", "email": "wmclaughlin@example.org", "phone_number": "(403)265-7488x96378", "passport_number": "912893652", "nationality": "Saint Barthelemy"}
# Key: None, Value: {"customer_id": 812, "first_name": "Miranda", "last_name": "Jones", "email": "darius80@example.net", "phone_number": "001-619-874-9349x99731", "passport_number": "929632185", "nationality": "French Guiana"}
# Key: None, Value: {"customer_id": 813, "first_name": "Kristi", "last_name": "Nelson", "email": "danielpetty@example.com", "phone_number": "+1-474-592-9083x20331", "passport_number": "614181204", "nationality": "Congo"}
# Key: None, Value: {"customer_id": 814, "first_name": "Paul", "last_name": "Hamilton", "email": "wernerjoseph@example.net", "phone_number": "779.776.4008x7838", "passport_number": "X31047736", "nationality": "Dominican Republic"}
# Key: None, Value: {"customer_id": 815, "first_name": "Tammy", "last_name": "Craig", "email": "coxkelly@example.com", "phone_number": "(261)446-4297x6250", "passport_number": "I08546381", "nationality": "Mongolia"}
# Key: None, Value: {"customer_id": 816, "first_name": "Matthew", "last_name": "Alvarez", "email": "kimberlyrobinson@example.com", "phone_number": "001-738-236-0824x84168", "passport_number": "153151735", "nationality": "Honduras"}
# Key: None, Value: {"customer_id": 817, "first_name": "Christian", "last_name": "Hoffman", "email": "darren73@example.com", "phone_number": "001-871-923-3562x33587", "passport_number": "K24724785", "nationality": "Chad"}
# Key: None, Value: {"customer_id": 818, "first_name": "Alexandra", "last_name": "Hart", "email": "ejohnson@example.com", "phone_number": "(758)549-7665x1901", "passport_number": "665159578", "nationality": "United Kingdom"}
# Key: None, Value: {"customer_id": 819, "first_name": "Stephanie", "last_name": "Floyd", "email": "wcabrera@example.net", "phone_number": "328-257-8666x23156", "passport_number": "716298685", "nationality": "Trinidad and Tobago"}
# Key: None, Value: {"customer_id": 820, "first_name": "Ashley", "last_name": "Stephens", "email": "peterslaurie@example.net", "phone_number": "(775)805-3758x66148", "passport_number": "W57563677", "nationality": "Bermuda"}
# Key: None, Value: {"customer_id": 821, "first_name": "Joseph", "last_name": "Mcdonald", "email": "patriciaanderson@example.org", "phone_number": "2257400340", "passport_number": "O33259851", "nationality": "Panama"}
# Key: None, Value: {"customer_id": 822, "first_name": "Harry", "last_name": "Garrett", "email": "michael63@example.org", "phone_number": "+1-329-803-2249x257", "passport_number": "221969318", "nationality": "Libyan Arab Jamahiriya"}
# Key: None, Value: {"customer_id": 823, "first_name": "Melissa", "last_name": "Wilson", "email": "david75@example.org", "phone_number": "(836)999-8389x55248", "passport_number": "327556580", "nationality": "Samoa"}
# Key: None, Value: {"customer_id": 824, "first_name": "Melanie", "last_name": "Lindsey", "email": "fgiles@example.net", "phone_number": "+1-929-541-1190x24595", "passport_number": "T25046775", "nationality": "Andorra"}
# Key: None, Value: {"customer_id": 825, "first_name": "Timothy", "last_name": "Henderson", "email": "ifrazier@example.org", "phone_number": "(353)612-3114x730", "passport_number": "O50873255", "nationality": "Madagascar"}
# Key: None, Value: {"customer_id": 826, "first_name": "Michael", "last_name": "Johnson", "email": "christophermejia@example.org", "phone_number": "001-531-222-5538x004", "passport_number": "Z14745042", "nationality": "Gabon"}
# Key: None, Value: {"customer_id": 827, "first_name": "Peggy", "last_name": "Jones", "email": "philip49@example.org", "phone_number": "3483934821", "passport_number": "105698301", "nationality": "Venezuela"}
# Key: None, Value: {"customer_id": 828, "first_name": "Cynthia", "last_name": "Craig", "email": "susan88@example.org", "phone_number": "(869)510-9494x399", "passport_number": "T26205618", "nationality": "Ukraine"}
# Key: None, Value: {"customer_id": 829, "first_name": "Kimberly", "last_name": "Miller", "email": "carol09@example.com", "phone_number": "765.865.4716x694", "passport_number": "R21538567", "nationality": "Bosnia and Herzegovina"}
# Key: None, Value: {"customer_id": 830, "first_name": "Sharon", "last_name": "Chavez", "email": "elliottnathan@example.org", "phone_number": "757.524.4174", "passport_number": "173038775", "nationality": "Malta"}
# Key: None, Value: {"customer_id": 831, "first_name": "Stephen", "last_name": "Anderson", "email": "obryant@example.net", "phone_number": "(616)941-6914x767", "passport_number": "L10895931", "nationality": "Eritrea"}
# Key: None, Value: {"customer_id": 832, "first_name": "Eric", "last_name": "Butler", "email": "calvinhopkins@example.net", "phone_number": "771-398-9740", "passport_number": "R34502652", "nationality": "Senegal"}
# Key: None, Value: {"customer_id": 833, "first_name": "David", "last_name": "Obrien", "email": "gcarr@example.net", "phone_number": "263-725-5836x13972", "passport_number": "C29547258", "nationality": "Swaziland"}
# Key: None, Value: {"customer_id": 834, "first_name": "Lawrence", "last_name": "Morales", "email": "jacquelineparks@example.net", "phone_number": "432.811.2824x40701", "passport_number": "E48580503", "nationality": "Swaziland"}
# Key: None, Value: {"customer_id": 835, "first_name": "Tonya", "last_name": "Casey", "email": "deanna66@example.net", "phone_number": "(694)972-5815x6149", "passport_number": "398527668", "nationality": "French Polynesia"}
# Key: None, Value: {"customer_id": 836, "first_name": "Hannah", "last_name": "Duke", "email": "jessica45@example.net", "phone_number": "2562914660", "passport_number": "143741497", "nationality": "Equatorial Guinea"}
# Key: None, Value: {"customer_id": 837, "first_name": "Rachel", "last_name": "Newman", "email": "andersonmolly@example.com", "phone_number": "(469)584-8921x608", "passport_number": "200171138", "nationality": "United States of America"}
# Key: None, Value: {"customer_id": 838, "first_name": "Tracy", "last_name": "Adams", "email": "stephanie48@example.org", "phone_number": "001-415-384-8874", "passport_number": "T44734411", "nationality": "Northern Mariana Islands"}
# Key: None, Value: {"customer_id": 839, "first_name": "Ashley", "last_name": "Ingram", "email": "dawn13@example.net", "phone_number": "001-885-329-3371x146", "passport_number": "014229024", "nationality": "Israel"}
# Key: None, Value: {"customer_id": 840, "first_name": "Lauren", "last_name": "Simpson", "email": "chavezangela@example.org", "phone_number": "(709)267-9121x78915", "passport_number": "M90619938", "nationality": "Turks and Caicos Islands"}
# Key: None, Value: {"customer_id": 841, "first_name": "Stephanie", "last_name": "Olson", "email": "brianburke@example.net", "phone_number": "711.897.0843", "passport_number": "314584628", "nationality": "Venezuela"}
# Key: None, Value: {"customer_id": 842, "first_name": "Michelle", "last_name": "Petersen", "email": "christopher25@example.com", "phone_number": "239.878.2692", "passport_number": "X15869564", "nationality": "Saint Lucia"}
# Key: None, Value: {"customer_id": 843, "first_name": "Bethany", "last_name": "Welch", "email": "johnoliver@example.org", "phone_number": "(907)892-5344", "passport_number": "D07544815", "nationality": "Romania"}
# Key: None, Value: {"customer_id": 844, "first_name": "Jared", "last_name": "Ingram", "email": "stuartpearson@example.net", "phone_number": "6722753978", "passport_number": "J52294133", "nationality": "Bahrain"}
# Key: None, Value: {"customer_id": 845, "first_name": "Jorge", "last_name": "Meyers", "email": "ngonzalez@example.com", "phone_number": "+1-460-216-6517", "passport_number": "972029157", "nationality": "Niger"}
# Key: None, Value: {"customer_id": 846, "first_name": "Andrea", "last_name": "Daniel", "email": "rodgerscharles@example.net", "phone_number": "001-751-253-3702x02493", "passport_number": "692775046", "nationality": "Greece"}
# Key: None, Value: {"customer_id": 847, "first_name": "Alyssa", "last_name": "Price", "email": "gmartinez@example.org", "phone_number": "+1-507-812-2750x226", "passport_number": "586418033", "nationality": "Denmark"}
# Key: None, Value: {"customer_id": 848, "first_name": "Paul", "last_name": "Berry", "email": "dblankenship@example.com", "phone_number": "713-590-8518", "passport_number": "O77325810", "nationality": "Togo"}
# Key: None, Value: {"customer_id": 849, "first_name": "Karina", "last_name": "Reynolds", "email": "snyderamy@example.org", "phone_number": "719.522.5082", "passport_number": "W93261992", "nationality": "United Arab Emirates"}
# Key: None, Value: {"customer_id": 850, "first_name": "Debra", "last_name": "Smith", "email": "tnunez@example.net", "phone_number": "+1-786-685-1155", "passport_number": "R40240351", "nationality": "Isle of Man"}
# Key: None, Value: {"customer_id": 851, "first_name": "Kelly", "last_name": "Maxwell", "email": "michael44@example.com", "phone_number": "(513)477-9116x520", "passport_number": "651736910", "nationality": "Sierra Leone"}
# Key: None, Value: {"customer_id": 852, "first_name": "Donald", "last_name": "Evans", "email": "jadelee@example.org", "phone_number": "(994)812-7882x548", "passport_number": "688713537", "nationality": "Monaco"}
# Key: None, Value: {"customer_id": 853, "first_name": "Aaron", "last_name": "Cline", "email": "kholt@example.org", "phone_number": "+1-908-393-8211", "passport_number": "346458860", "nationality": "Estonia"}
# Key: None, Value: {"customer_id": 854, "first_name": "Chad", "last_name": "Jackson", "email": "wilsonmackenzie@example.org", "phone_number": "+1-472-803-7573x2339", "passport_number": "885019773", "nationality": "Trinidad and Tobago"}
# Key: None, Value: {"customer_id": 855, "first_name": "Gabriela", "last_name": "Gonzales", "email": "ytaylor@example.org", "phone_number": "001-343-677-2512x828", "passport_number": "V98444261", "nationality": "Guadeloupe"}

# %%
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Create Delta Table") \
    .getOrCreate()

# Sample data for creating the Delta table
data = [(1, "John Doe", "2024-10-09 10:00:00"),
        (2, "Jane Smith", "2024-10-09 10:05:00")]

columns = ["id", "name", "timestamp"]

# Create a DataFrame
df = spark.createDataFrame(data, columns)
df.show()
# Write the DataFrame to a Delta table
df.write.mode("overwrite").format("delta").saveAsTable("test_Data")
  # Specify your Delta Lake path

# Register the Delta table in the catalog (optional)
#spark.sql("CREATE TABLE bronze_customer_table USING DELTA LOCATION '/path/to/delta/bronze_customer_table'")
# Out:
# StatementMeta(, d0b77ee1-0ffd-4bb7-9a93-8156c8bb2303, 5, Finished, Available, Finished)
# +---+----------+-------------------+
# | id|      name|          timestamp|
# +---+----------+-------------------+
# |  1|  John Doe|2024-10-09 10:00:00|
# |  2|Jane Smith|2024-10-09 10:05:00|
# +---+----------+-------------------+
